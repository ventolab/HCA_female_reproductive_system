# %% [markdown]
# # 00aii · Cell type annotation (**Immune** analytical manifold, acrosslifespan/no nEMC)
#
# **Sections:**
# 1. Load integrated .h5ad object from `00ai_scvi_integration_immune_acrosslifespan_noEMC.ipynb`
# 2. View existing metadata via UMAP
# 3. Plot previous cell type annotations
# 4. Optional: re-cluster specific Leiden clusters
# 5. TF-IDF: identify quick markers across Leiden clusters
# 6. Visualise known markers via dotplots (UMAP visualisation of the same markers, and others, was paralleled but omitted here for space)
# 7. Manually map cell types to Leiden clusters along with accompanying cell ontology
# 8. Save .h5ad
# 9. Contextualise cell type annotations within metadata with bar plots
#
# *Note:* Several rounds of iteration within Sections 4-6 was performed prior to finalising cell type annotations.

# %% [markdown]
# ## Configuration

# %%
import os, sys

# ── Paths ─────────────────────────────────────────────────────────────────────
MAIN_DIR        = "/nfs/team292/projects/PanTissue/"
INPUT_H5AD      = os.path.join(MAIN_DIR, "results/temp/01_integration/integrated_scvi_acrosslifespan_noHormones_immune.h5ad")
OUTPUT_DIR      = os.path.join(MAIN_DIR, "results/temp/02_annotation/immune/acrosslifespan/noHormones/")
MARKERS_PY      = os.path.join(MAIN_DIR, "code/working/ck18/markers.py")
MARKERS_IMMUNE_PY = os.path.join(MAIN_DIR, "code/working/ck18/markers_immune.py")
FORANNOTION_H5AD   = os.path.join(OUTPUT_DIR, "forannotation_acrosslifespan_noHormones_immune.h5ad")
ANNOTATED_H5AD   = os.path.join(OUTPUT_DIR, "annotated_acrosslifespan_noHormones_immune.h5ad")
ONTOLOGY_CSV  = os.path.join(MAIN_DIR, "data/freeze/ontology/HCA_annotation_ontology_L1_L4_immune.csv")

os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── Column names in obs ───────────────────────────────────────────────────────
DATASET_COL  = "dataset"
DONOR_COL    = "Donor_id"
SAMPLE_COL   = "sample"
ORGAN_COL    = "Organ"
LEIDEN_COL   = "leiden"

# QC columns to use in boxplots — adjust to what is present in your obs
QC_COLS = [
    "n_genes_by_counts",
    "n_genes",
    "percent_mito",
    # "phase",
    "health_score",
    'stress_score_vandenBrink',
    "doublet_scores",
]

# ── Misc ──────────────────────────────────────────────────────────────────────
RANDOM_SEED = 42

# ── TF-IDF parameters ─────────────────────────────────────────────────────────
TFIDF_DOWNSAMPLE_N = 100    # cells per celltype_leiden group
TFIDF_N_MARKERS    = 10
TFIDF_FDR          = 0.01
TFIDF_EXPRESS_CUT  = 0.9

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings("ignore")

import importlib.util
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import anndata as ad
import scanpy as sc

sys.path.append('/nfs/team292/projects/PanTissue/code/working/lg18/utils/')
from panatlas_utils import quick_markers, Barplot, filterTFIDF, plotUMAP_per_value, get_available_markers, plot_obs_facets

sc.settings.figdir = os.path.join(OUTPUT_DIR, "figures/")
sc.settings.verbosity = 3
sc.set_figure_params(dpi=100, frameon=False, figsize=(6, 5))

print(f"anndata : {ad.__version__}")
print(f"scanpy  : {sc.__version__}")

# %% [markdown]
# # 1. Load integrated object

# %%
# adata = ad.read_h5ad(INPUT_H5AD)
adata = ad.read_h5ad(FORANNOTION_H5AD)
print(adata)
print("\nobs columns:", adata.obs.columns.tolist())

# %%
adata.obs.head(1)

# %% [markdown]
# # 2. Overview UMAPs

# %%
# Fix typos
adata.obs["Menstrual_stage"] = (
    adata.obs["Menstrual_stage"]
    .replace("Unkown", "Unknown")
    .astype("category") # Ensure it stays/becomes a category for Scanpy
)
# Fix typos
adata.obs["Menstrual_stage"] = (
    adata.obs["Menstrual_stage"]
    .replace("Postmenopausal", "Postmenopause")
    .astype("category") # Ensure it stays/becomes a category for Scanpy
)
# Fix typos
adata.obs["Menstrual_stage"] = (
    adata.obs["Menstrual_stage"]
    .replace("Secreotry", "Secretory")
    .astype("category") # Ensure it stays/becomes a category for Scanpy
)
# Fix typos
adata.obs["Organ_part"] = (
    adata.obs["Organ_part"]
    .replace("Mentrual fluid", "Menstrual fluid")
    .astype("category") # Ensure it stays/becomes a category for Scanpy
)
# Fix typos
adata.obs["Menstrual_stage_short"] = (
    adata.obs['Menstrual_stage'].astype(str).str.split(" ").str[0]
)
adata.obs["Menstrual_stage_short"] = (
    adata.obs["Menstrual_stage_short"]
    .replace("Not", "Not applicable")
)

print(adata.obs["Menstrual_stage_short"].value_counts())

# Rename menstrual fluid
mask = (adata.obs['dataset'] == "uterus_adult_menstrualfluid_sanger-denoised") & (adata.obs['Menstrual_stage_short'] == "Menstrual")
adata.obs.loc[mask, 'Menstrual_stage_short'] = "Menstrual_fluid"

# %%
# ── Core metadata ─────────────────────────────────────────────────────────────
_meta_cols = [DATASET_COL, ORGAN_COL] + ['Tissue_ROI', 'Organ_part', 'Developmental_stage']
_meta_cols = [c for c in _meta_cols if c in adata.obs.columns]
sc.pl.umap(
    adata,
    color           = _meta_cols,
    ncols           = 1,
    legend_loc      = "right margin",
    legend_fontsize = 7,
    save            = "_01_metadata_acrosslifespan_noHormones_immune.png",
)

# %%
# ── QC metrics ─────────────────────────────────────────────────────────────
_meta_cols = QC_COLS
_meta_cols = [c for c in _meta_cols if c in adata.obs.columns]
sc.pl.umap(
    adata,
    color           = _meta_cols,
    ncols           = 1,
    legend_loc      = "right margin",
    legend_fontsize = 7,
    save            = "_01_qc_acrosslifespan_noHormones_immune.png",
)

# %%
plot_obs_facets(adata, "Organ", n_cols=6)

# %%
plot_obs_facets(adata, "Developmental_stage", n_cols=6)

# %%
sc.pl.umap(
    adata,
    color           = "Menstrual_stage_short",
    title           = "UMAP – menstrual stage",
    legend_loc      = "right margin",
    legend_fontsize = 8,
    save            = "_01_menstrual_stage_acrosslifespan_noHormones_immune.png",
)

# %%
sc.pl.umap(
    adata,
    color           = "Developmental_stage",
    title           = "UMAP – developmental stage",
    legend_loc      = "right margin",
    legend_fontsize = 8,
    save            = "_01_developmental_stage_acrosslifespan_noHormones_immune.png",
)

# %%
# ── Cell cycle phase and doublet score ────────────────────────────────────────
_qc_umap = [c for c in ["phase", "doublet_scores"] if c in adata.obs.columns]
if _qc_umap:
    sc.pl.umap(
        adata,
        color      = _qc_umap,
        ncols      = 2,
        save       = "_02_cellcycle_doublet_acrosslifespan_noHormones_immune.png",
    )
else:
    print("No cell-cycle / doublet columns found in obs.")

# %%
sc.pl.umap(
    adata,
    color           = LEIDEN_COL,
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "Leiden",
    save            = "_03_leiden_acrosslifespan_noHormones_immune.png",
)

# %% [markdown]
# # 3. Plot previous annotations

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join("/nfs/team292/projects/PanTissue/data/freeze/annotations_author-original/HECA_immune.csv")   # lineage from fetal_02_annotation_fetal
PRIOR_ANN_COL = "immune_subcluster_labels"
PRIOR_BAR_COL = "barcode"


# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=PRIOR_BAR_COL)
    prior.index = prior.index.str.split('-').str[0] + "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'HECA_celltype'})

# %%
sc.pl.umap(
    adata,
    color           = "HECA_celltype",
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "HECA_celltype",
    # save            = "_05_lineage_postnatal.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join("/nfs/team292/projects/PanTissue/data/freeze/annotations_author-original/fallopiantubes_Sanger2026_immune_20160422.csv")   # lineage from fetal_02_annotation_fetal
PRIOR_ANN_COL = "cell_coarse"
PRIOR_BAR_COL = "barcode"


# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=0)
    prior.index = prior.index.astype(str) #+ "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'ECTOPIC_cell_coarse'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "ECTOPIC_cell_coarse",
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "ECTOPIC_cell_coarse",
    # save            = "_05_lineage_postnatal.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join("/nfs/team292/projects/PanTissue/data/freeze/annotations_author-original/fallopiantubes_Sanger2026_immune_20160422.csv")   # lineage from fetal_02_annotation_fetal
PRIOR_ANN_COL = "cell_type"
PRIOR_BAR_COL = "barcode"


# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=0)
    prior.index = prior.index.astype(str) #+ "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'ECTOPIC_cell_type'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "ECTOPIC_cell_type",
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "ECTOPIC_cell_type",
    # save            = "_05_lineage_postnatal.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join("/nfs/team292/projects/PanTissue/data/freeze/annotations_author-original/fallopiantubes_Sanger2026_immune_20160422.csv")   # lineage from fetal_02_annotation_fetal
PRIOR_ANN_COL = "cell_state"
PRIOR_BAR_COL = "barcode"


# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=0)
    prior.index = prior.index.astype(str) #+ "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'ECTOPIC_cell_state'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "ECTOPIC_cell_state",
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "ECTOPIC_cell_state",
    # save            = "_05_lineage_postnatal.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join("/nfs/team292/ja35/To_Christina/immune_annotation_05052026.csv")   # lineage from fetal_02_annotation_fetal
PRIOR_ANN_COL = "cell_type"
# PRIOR_BAR_COL = "barcode"

# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=0)
    # prior.rename(index=lambda x: x.replace('-Sanger_pediatric-Sanger_nonFetal', ''), inplace=True)
    # prior.rename(index=lambda x: x.replace('-Sanger_adult-Sanger_nonFetal', ''), inplace=True)
    # prior.rename(index=lambda x: x.replace('-Sanger_Fetal', ''), inplace=True)
    # prior.index = prior.index.astype(str) + "-1"
    prior.index = prior.index.astype(str).str.replace(r'-.*$', '-1', regex=True)
    if PRIOR_ANN_COL in prior.columns:        
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'ovaries2026_celltype_UPDATED'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "ovaries2026_celltype_UPDATED",
    legend_loc      = "on data",
    legend_fontsize = 8,
    title           = "ovaries2026_celltype_UPDATED",
    # save            = "_05_lineage_postnatal.png",
)

# %%
plot_obs_facets(adata, "ovaries2026_celltype_UPDATED", n_cols=5)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join(f"/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/postnatal/20260507_postnatal_immune_annotations.csv")
PRIOR_ANN_COL = "celltype"
PRIOR_BAR_COL = "barcode"

# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=PRIOR_BAR_COL)
    # prior.index = prior.index.astype(str) + "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'postnatal_immune_celltype'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "postnatal_immune_celltype",
    legend_loc      = "on data",
    legend_fontsize = 2,
    title           = "postnatal_immune_celltype",
    save            = "_04_postnatal_immune_celltype_mapped_on_acrosslifespan_noHormones_immune.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join(f"/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/fetal/20260506_fetal_immune_annotations.csv")
PRIOR_ANN_COL = "celltype"
PRIOR_BAR_COL = "barcode"

# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=PRIOR_BAR_COL)
    # prior.index = prior.index.astype(str) + "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'fetal_immune_celltype'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "fetal_immune_celltype",
    legend_loc      = "on data",
    legend_fontsize = 2,
    title           = "fetal_immune_celltype",
    save            = "_04_fetal_immune_celltype_mapped_on_acrosslifespan_noHormones_immune.png",
)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join(f"/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/Hormones/20260511_acrosslifespan_immune_annotations.csv")
PRIOR_ANN_COL = "celltype"
PRIOR_BAR_COL = "barcode"

# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=PRIOR_BAR_COL)
    # prior.index = prior.index.astype(str) + "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'acrosslifespan_Hormones_immune_celltype'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "acrosslifespan_Hormones_immune_celltype",
    legend_loc      = "on data",
    legend_fontsize = 2,
    title           = "acrosslifespan_Hormones_immune_celltype",
    save            = "_04_acrosslifespan_Hormones_immune_celltype_mapped_on_acrosslifespan_noHormones_immune.pdf",
)

# %%
adata.obs.head(1)

# %%
adata.obs_names = adata.obs["sample_id_barcode_copy"]
adata.obs.drop(columns=["acrosslifespan_noHormones_MonoMaccDC2_celltype"], inplace=True)

# %%
# ── Prior annotation (optional) ───────────────────────────────────────────────
# Maps a column from a prior annotation CSV into adata.obs (no subsetting).
# The CSV must have a 'barcode' index column. Set to None to skip.
PRIOR_ANN_CSV = os.path.join(f"/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/00_monomacscDC2/20260512_acrosslifespan_noHormones_immune_monomacscDC2_annotations.csv")
PRIOR_ANN_COL = "celltype"
PRIOR_BAR_COL = "barcode"

# ── Map prior annotation to obs ───────────────────────────────────────────────
# Reads PRIOR_ANN_CSV and maps PRIOR_ANN_COL into adata.obs by barcode.
# Cells not present in the CSV receive NaN. No subsetting is performed.

if PRIOR_ANN_CSV and os.path.exists(PRIOR_ANN_CSV):
    prior = pd.read_csv(PRIOR_ANN_CSV, index_col=PRIOR_BAR_COL)
    # prior.index = prior.index.astype(str) + "-1"
    if PRIOR_ANN_COL in prior.columns:
        adata.obs[PRIOR_ANN_COL] = adata.obs_names.map(prior[PRIOR_ANN_COL])
        n_mapped = adata.obs[PRIOR_ANN_COL].notna().sum()
        print(f"Mapped '{PRIOR_ANN_COL}' from {PRIOR_ANN_CSV}")
        print(f"  {n_mapped:,} / {adata.n_obs:,} cells annotated")
        print(adata.obs[PRIOR_ANN_COL].value_counts(dropna=False))
    else:
        print(f"WARNING: column '{PRIOR_ANN_COL}' not found in {PRIOR_ANN_CSV}")
        print(f"  Available columns: {prior.columns.tolist()}")
elif PRIOR_ANN_CSV:
    print(f"WARNING: prior annotation CSV not found:\n  {PRIOR_ANN_CSV}")
else:
    print("No prior annotation CSV specified (PRIOR_ANN_CSV = None) — skipping.")

# Rename
adata.obs = adata.obs.rename(columns={PRIOR_ANN_COL: 'acrosslifespan_noHormones_MonoMaccDC2_celltype'})

# %%
# 3. Cast to category for plotting
sc.pl.umap(
    adata,
    color           = "acrosslifespan_noHormones_MonoMaccDC2_celltype",
    legend_loc      = "on data",
    legend_fontsize = 2,
    title           = "acrosslifespan_noHormones_MonoMaccDC2_celltype",
    save            = "_04_acrosslifespan_noHormones_MonoMaccDC2_celltype_mapped_on_acrosslifespan_noHormones_immune.pdf",
)

# %%
adata.obs.head(1)

# %% [markdown]
# # 4. Optional: re-cluster specific Leiden clusters
#
# Duplicate the cell below for each cluster that needs splitting.

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['45']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['43']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['39']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['38']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['38']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['38']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['38']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['37']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['30']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['29']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['28']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['27']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['26']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['27']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['23']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['20']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['19']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['16']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['15']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['11']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['13']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['10']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['9']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['9']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['6']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['4']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['93']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['81']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['78']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['74']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['65']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['48']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['9']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
# ── Template — duplicate this cell for each cluster to re-split ───────────────

sc.tl.leiden(adata, resolution=0.3, restrict_to=('leiden', ['109']),
             flavor='igraph', n_iterations=2, directed=False)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden_R'] = adata.obs['leiden_R'].cat.rename_categories(
    [str(i) for i in range(len(adata.obs['leiden_R'].cat.categories))]
)
sc.pl.umap(adata, color='leiden_R', legend_loc='on data', legend_fontsize=9)

adata.obs['leiden'] = adata.obs['leiden_R']

# %%
adata.obs['leiden'].unique()

# %%
plot_obs_facets(adata, "leiden", n_cols=6)

# %%
sc.pl.umap(
    adata,
    color           = LEIDEN_COL,
    legend_loc      = "on data",
    legend_fontsize = 3,
    title           = "Leiden",
    palette         = palette,
    save            = "_03_leiden_acrosslifespan_noHormones_immune.png",
)

# %% [markdown]
# # 5. TF-IDF: quick marker identification

# %%
adata.obs.head(1)

# %%
ANNOT_COL = "celltype_HCA"

# %%
mask = ~adata.var_names.str.startswith("DEPRECATED_")
bdata = adata[:, mask].copy()

print(f"Num genes removed: {(adata.n_vars)-(bdata.n_vars)}")

# %%
to_keep = [
    'Immune_uftLAM',
    'Immune_Mac_LYVE1hi',
    # 'Immune_oLAM'
]

bdata = adata[adata.obs[ANNOT_COL].isin(to_keep)].copy()
print(f"Num cells removed: {(adata.n_obs)-(bdata.n_obs)}")
print(f"Num cells remaining: {bdata.n_obs}")
bdata.obs[ANNOT_COL].value_counts()

# %%
from scipy.sparse import csr_matrix, issparse
from scipy.stats import hypergeom
from statsmodels.stats.multitest import multipletests


def quick_markers(
    adata,
    cluster_key,
    cell_groups=None,
    layer=None,
    n_markers=10,
    fdr=0.01,
    express_cut=0.9,
    r_output=False
):
    """
    Identifies top N markers for each cluster in an AnnData object
    using a TF-IDF-based strategy similar to SoupX.
    """

    # —— Subset cells ———————————————————————————————————————————————————
    if cell_groups is not None:
        adata_ = adata[adata.obs[cluster_key].isin(cell_groups)].copy()
    else:
        adata_ = adata.copy()

    # —— Ensure categorical labels ——————————————————————————————————————
    adata_.obs[cluster_key] = (
        adata_.obs[cluster_key]
        .astype("category")
        .cat.remove_unused_categories()
    )

    cluster_cat = adata_.obs[cluster_key].cat
    cluster_names = cluster_cat.categories
    clusters = cluster_cat.codes.to_numpy()
    unique_clusters = np.unique(clusters)

    # —— Extract expression matrix ——————————————————————————————————————
    if layer is not None:
        toc = (
            csr_matrix(adata_.layers[layer])
            if not issparse(adata_.layers[layer])
            else adata_.layers[layer]
        )
    else:
        toc = (
            csr_matrix(adata_.X)
            if not issparse(adata_.X)
            else adata_.X
        )

    # —— Binarize expression ————————————————————————————————————————————
    toc_bin = (toc > express_cut).astype(int)

    # —— Cluster counts —————————————————————————————————————————————————
    cl_counts = np.asarray([
        np.sum(clusters == cl)
        for cl in unique_clusters
    ]).reshape(-1, 1)

    # —— Observed gene frequencies ——————————————————————————————————————
    n_obs = np.asarray([
        np.asarray(
            toc_bin[clusters == cl, :].sum(axis=0)
        ).flatten()
        for cl in unique_clusters
    ])

    n_tot = n_obs.sum(axis=0)
    n_tot_safe = np.where(n_tot == 0, 1, n_tot)

    # —— TF-IDF transformation ———————————————————————————————————————————
    tf = n_obs / cl_counts
    idf = np.log(len(clusters) / n_tot_safe)
    tf_idf = tf * idf

    # —— Global and outside-group frequencies ————————————————————————————
    gene_freq_outside_cluster = (
        (n_tot - n_obs)
        / np.maximum(len(clusters) - cl_counts, 1)
    )

    gene_freq_global = n_tot / len(clusters)

    # —— Second-best tf cluster ——————————————————————————————————————————
    second_best_tf = np.zeros_like(tf)
    second_best_cluster_idx = np.zeros(tf.shape[1], dtype=int)

    for gene_idx in range(tf.shape[1]):

        tf_scores = tf[:, gene_idx]

        if len(tf_scores) > 1:
            second_best_idx = np.argsort(tf_scores)[-2]
        else:
            second_best_idx = 0

        second_best_tf[:, gene_idx] = tf_scores[second_best_idx]
        second_best_cluster_idx[gene_idx] = second_best_idx

    # —— Hypergeometric test —————————————————————————————————————————————
    p_values = np.array([
        hypergeom.sf(
            n_obs[i] - 1,
            len(clusters),
            n_tot,
            cl_counts[i]
        )
        for i in range(len(unique_clusters))
    ])

    # —— FDR correction ——————————————————————————————————————————————————
    p_flat = p_values.flatten()

    reject, q_flat, _, _ = multipletests(
        p_flat,
        alpha=fdr,
        method='fdr_bh'
    )

    q_values = q_flat.reshape(p_values.shape)

    # —— Select top markers ———————————————————————————————————————————————
    top_markers = {cl: [] for cl in unique_clusters}

    for gene_idx in range(tf_idf.shape[1]):

        for cl in unique_clusters:

            q_val = q_values[cl, gene_idx]

            if not np.isnan(q_val) and q_val < fdr:

                top_markers[cl].append(
                    (gene_idx, tf_idf[cl, gene_idx])
                )

    for cl in top_markers:

        top_markers[cl].sort(key=lambda x: x[1], reverse=True)

        top_markers[cl] = [
            gene_idx
            for gene_idx, _
            in top_markers[cl][:n_markers]
        ]

    # —— Build output table ———————————————————————————————————————————————
    marker_data = []

    for cl, markers in top_markers.items():

        for gene_idx in markers:

            second_best_cl = second_best_cluster_idx[gene_idx]

            marker_data.append({

                'gene': adata_.var_names[gene_idx],
                'cluster': cluster_names[cl],

                'tf': tf[cl, gene_idx],
                'idf': idf[gene_idx],
                'tf_idf': tf_idf[cl, gene_idx],

                'gene_frequency_outside_cluster':
                    gene_freq_outside_cluster[cl, gene_idx],

                'gene_frequency_global':
                    gene_freq_global[gene_idx],

                'second_best_tf':
                    second_best_tf[cl, gene_idx],

                'second_best_cluster':
                    cluster_names[second_best_cl],

                'pval': p_values[cl, gene_idx],
                'qval': q_values[cl, gene_idx]
            })

    markers = pd.DataFrame(marker_data)

    if markers.shape == (0, 0):

        markers = pd.DataFrame(columns=[
            'gene', 'cluster', 'tf', 'idf', 'tf_idf',
            'gene_frequency_outside_cluster',
            'gene_frequency_global',
            'second_best_tf',
            'second_best_cluster',
            'pval', 'qval'
        ])

    # —— SoupX-compatible output ——————————————————————————————————————————
    if r_output:

        cols = [
            'gene', 'cluster', 'tf',
            'gene_frequency_outside_cluster',
            'second_best_tf',
            'gene_frequency_global',
            'second_best_cluster',
            'tf_idf', 'idf', 'qval'
        ]

        markers = markers[cols]

        markers.columns = [
            'gene',
            'cluster',
            'geneFrequency',
            'geneFrequencyOutsideCluster',
            'geneFrequencySecondBest',
            'geneFrequencyGlobal',
            'secondBestClusterName',
            'tfidf',
            'idf',
            'qval'
        ]

    return markers

# %%
# Run TF-IDF-based marker identification on clustered data
markers = quick_markers(
    bdata,
    cluster_key=ANNOT_COL,
    layer=None,
    n_markers=20,
    r_output=True
)

markers.to_csv(f"{OUTPUT_DIR}tf-idf_markers_uftLAM_vs_Mac_LYVE1hi_acrosslifespan_noHormones_immune.csv")
markers.head()

# %%
def plot_tfidf(
    adata,
    markers:     pd.DataFrame,
    top_n:       int=10,
    group:       str="leiden",
    plot_unique: bool=False,
    outdir:      str=None,
    filename:    str=None,
    save:        bool=False
):
    """
    Visualises top TF-IDF-based markers per cluster in a dotplot.

    Parameters
    ----------
    adata : AnnData
        The annotated data matrix of shape `n_obs` × `n_vars`. Rows correspond to cells and columns to genes
    markers : pd.DataFrame
        A :class:`pd.DataFrame` that is output from quick_markers() (see function for structure)
    top_n : int, default=10
        How many top TF-IDF markers to plot per cluster. Default is 10
    group : str, default='leiden'
        Column name in `adata.obs` to group top markers by. Defaults to Leiden (unannotated clusters generated
        by Leiden algorithm)
    plot_unique : bool, default=False
        Whether to plot an unordered set of unique top_n markers over all clusters. Default is `False`, outputting
        a dotplot grouped by cluster
    outdir, save : optional
        Figure saving parameters
    """

    # —— Build marker dictionary and unique marker set ———————————————————
    unique_markers = set()
    all_markers    = dict()

    for cluster, df in markers.groupby("cluster"):
        top_markers    = [g for g in df["gene"]][:top_n]
        all_markers[cluster] = top_markers
        tmp_genes      = set(top_markers)
        unique_markers = unique_markers.union(tmp_genes)

    unique_markers = sorted(unique_markers)

    # —— Identify clusters represented in markers DataFrame ——————————————
    clusters_to_plot = markers["cluster"].unique().tolist()

    # —— Subset adata to only the relevant cells —————————————————————————
    adata_subset = adata[adata.obs[group].isin(clusters_to_plot)].copy()

    # —— Plot dotplot ————————————————————————————————————————————————————
    with plt.rc_context({"font.size": 11, "figure.dpi": 80, "figure.figsize": (6, 2)}):

        if plot_unique == True:
            dp = sc.pl.dotplot(
                adata_subset,
                unique_markers,
                return_fig=True,
                standard_scale="var"
            )
        else:
            dp = sc.pl.dotplot(
                adata_subset,
                all_markers,
                groupby=group,
                return_fig=True,
                standard_scale="var"
            )

        dp.style(
            cmap=            "OrRd",
            dot_edge_color=  "black",
            dot_edge_lw=     0.8
        )

        if save is True and outdir and filename:
            dp.savefig(f"{outdir}tf-idf_{filename}.pdf")

    dp.show() if save == False else None

# %%
# Plot the markers dotplot and, if desired, save as PDF
plot_tfidf(
    bdata,
    markers,
    top_n=20,
    group=ANNOT_COL,
    outdir=os.path.join(OUTPUT_DIR, "figures/"),
    filename=f'uftLAM_vs_Mac_LYVE1hi_acrosslifespan_noHormones_immune',
    save=True
)

# %% [markdown]
# # 6. Plot known markers

# %% [markdown]
# ## Normalise for visualisation (raw counts frozen)

# %%
adata.raw = adata   # freeze raw counts
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
print("Raw counts frozen in adata.raw. adata.X now holds log-normalised expression.")

# %% [markdown]
# ## Load marker genes

# %%
spec = importlib.util.spec_from_file_location("markers", MARKERS_PY)
markers_mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(markers_mod)

# %%
# ── 1. Broad lineage markers ──────────────────────────────────────────────────
markers_lineage = getattr(markers_mod, "markers_lineage", {})
markers_lineage_avail = get_available_markers(markers_lineage, "Lineage markers", adata)

# %%
# ── 4. Macrophage postnatal markers, all tissues ──────────────────────────────
if hasattr(markers_mod, "markers_immune_macros"):
    markers_immMac = markers_mod.markers_immune_macros
    markers_immMac_avail = get_available_markers(markers_immMac, "Postnatal macrophage markers", adata)
else:
    print("WARNING: 'markers_immune_macros' not found.")
    markers_immMac_avail = {}

# %%
spec = importlib.util.spec_from_file_location("markers_immune", MARKERS_IMMUNE_PY)
markers_imm_mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(markers_imm_mod)

# %%
# ── 5. General T markers ──────────────────────────────────────────────────————
if hasattr(markers_imm_mod, "markers_masopust_T_general"):
    markers_gen_T = markers_imm_mod.markers_masopust_T_general
    markers_gen_T_avail = get_available_markers(markers_gen_T, "General T markers", adata)
else:
    print("WARNING: 'markers_masopust_T_general' not found.")
    markers_gen_T_avail = {}

# %%
# ── 6. CD4+ T subset markers ──────────────────────────────────────────────────
if hasattr(markers_imm_mod, "markers_masopust_CD4_T_subs"):
    markers_CD4_T = markers_imm_mod.markers_masopust_CD4_T_subs
    markers_CD4_T_avail = get_available_markers(markers_CD4_T, "CD4+ T subset markers", adata)
else:
    print("WARNING: 'markers_masopust_CD4_T_subs' not found.")
    markers_CD4_T_avail = {}

# %%
# ── 7. Memory T subset markers ─────────────────────────────────────────────────
if hasattr(markers_imm_mod, "markers_masopust_T_memory_subs"):
    markers_Tmem = markers_imm_mod.markers_masopust_T_memory_subs
    markers_Tmem_avail = get_available_markers(markers_Tmem, "Memory T cell markers", adata)
else:
    print("WARNING: 'markers_masopust_T_memory_subs' not found.")
    markers_Tmem_avail = {}

# %%
# ── 8. Exhausted T subset markers ──────────────────────────────────────────────
if hasattr(markers_imm_mod, "markers_masopust_T_ex_subs"):
    markers_Tex = markers_imm_mod.markers_masopust_T_ex_subs
    markers_Tex_avail = get_available_markers(markers_Tex, "Exhausted T cell markers", adata)
else:
    print("WARNING: 'markers_masopust_T_ex_subs' not found.")
    markers_Tex_avail = {}

# %%
# ── 9. Innate T subset markers ────────────────────────────────────────────────
if hasattr(markers_imm_mod, "markers_masopust_T_innate_subs"):
    markers_Tinn = markers_imm_mod.markers_masopust_T_innate_subs
    markers_Tinn_avail = get_available_markers(markers_Tinn, "Innate T cell markers", adata)
else:
    print("WARNING: 'markers_masopust_T_innate_subs' not found.")
    markers_Tinn_avail = {}

# %%
# ── 10. CD8+ T subset markers ────────────────────────────────────────────────———
if hasattr(markers_imm_mod, "markers_masopust_CD8_T_subs"):
    markers_CD8_T = markers_imm_mod.markers_masopust_CD8_T_subs
    markers_CD8_T_avail = get_available_markers(markers_CD8_T, "CD8+ T subset markers", adata)
else:
    print("WARNING: 'markers_masopust_CD8_T_subs' not found.")
    markers_CD8_T_avail = {}

# %%
markers = {
    'Neutrophils': ['ALPL', 'CXCR2', 'FCGR3B'],
    'cDC2': ['CD1C', 'CD1E', 'FCER1A', 'CD207'],
    
    'MO_CD14': ['S100A12', 'PLCB1'],
    'MO_CD16': ['FCGR3A', 'PTP4A3', 'CDKN1C'],
    
    'Mac_LYVE1': ['LYVE1', 'FOLR2', 'SELENOP'],
    'Mac_TREM2': ['TREM2']
    'Mac_EREG': [],
    
    'Cycling': ['MKI67', 'PCLAF']
}

# %% [markdown]
# ## Dotplots — markers × clusters

# %%
to_keep = [
    'Macrophages'
]

bdata = adata[adata.obs["L3"].isin(to_keep)].copy()
print(f"Num cells removed: {(adata.n_obs)-(bdata.n_obs)}")

# %%
# ── Broad lineage markers (doublet / contamination check) ─────────────────────
sc.pl.dotplot(
    bdata,
    var_names      = ['TREM2', 'APOE', 'CD9', 'SPP1', 'OLR1', 'CH25H', 'SORL1', 'APOC2', 'ALDH2'],
    groupby        = 'HCA_celltype_label',
    # use_raw        = True,
    standard_scale = "var",
    colorbar_title = "Mean expr\n(scaled)",
    # save           = "04a_leiden_linmarkers_acrosslifespan_immune_monomacscDC2.png",
)

# %%
# ── postnatal immune cell type markers ────────────────────────────────────────
if markers_immMac_avail:
    sc.pl.dotplot(
        adata,
        var_names      = markers_immMac_avail,
        groupby        = LEIDEN_COL,
        # use_raw        = True,
        standard_scale = "var",
        colorbar_title = "Mean expr\n(scaled)",
        save           = "04b_leiden_immMacmarkers_acrosslifespan_immune_monomacscDC2.png",
    )
else:
    print("Skipping dotplot — markers not loaded.")

# %% [markdown]
# # 7. Manual cell type annotation
#
# Fill in Leiden cluster IDs (integers) for each postnatal immune cell type.
# Leave empty lists `[]` for cell types not present or not yet identified.

# %%
# ── Fill in Leiden IDs as integers ────────────────────────────────────────────
# Example:  'Epi_FT_Cil': [3, 7]
celltype_to_leiden = {
    'Immune_HPC':[124],
    'Immune_MEMP': [122,123],
    'Immune_NMP_Promyelocytes': [9,10],
    
    'Immune_BasoEosino': [32],
    'Immune_Neutrophils': [59],
    'Immune_Mast':[28,29,30,31,33,34,35],
    'Immune_MegaPlat': [126],
    'Immune_EarlyMidErythroid': [125],                      # Cycling - erythroblasts
    'Immune_LateErythroid': [6],
    
    'Immune_cDC1': [38],
    'Immune_pDC':[19,20,21],
    'Immune_ASDC':[18],
    'Immune_mregDC':[60,61],
    
    'Immune_ProB': [72],
    'Immune_LargePreB': [69,70,71],
    'Immune_SmallPreB': [68,73],
    'Immune_ImmatureB': [66],
    'Immune_NaiveB':[67],
    'Immune_MemoryB':[64,65],
    'Immune_Plasma_κ':[0],
    'Immune_Plasma_λ':[1],
    
    'Immune_CD4_NaiveT':[114],                              # Modular annot: CD4+ TN
    'Immune_CD4_T_Unpolarised': [100,101,102,111],          # Modular annot: CD4+ T (A vs. M unclear)
    'Immune_CD4_Th17':[108,109],                            # Modular annot: CD4+ Th17
    'Immune_CD4_Th17_SCMlike':[56,57],                      # Modular annot: CD4+ Th2-SCM
    'Immune_CD4_Treg':[46,47],                              # Modular annot: CD4+ Treg (migration, diff state unclear)
    'Immune_CD8_NaiveT':[23,24,25,26,27],                   # Modular annot: CD8+ TN
    'Immune_CD8_T_RM':[110,115],                            # Modular annot: CD8+ TDrM
    'Immune_CD8_T_RM_GZMKhi':[92,93,94,95,75,112,116,121],  # Modular annot: CD8+ TDrM
    'Immune_CD8_T_EM': [78,80,83,86],                       # Modular annot: CD8+ TDM (lack homing receptors)
    'Immune_MAIT':[87,88,89,90,103,104,105],                # Modular annot: MAIT D Eff; 57 is MAIT S
    'Immune_NKT_γδT_Vδ1':[54,74,76,77],
    'Immune_γδT_Vγ9Vδ2':[91],
    'Immune_T_Cyc':[41,43,52],
    'Immune_CD4_Treg_Cyc': [45],
    
    'Immune_ILC3_NCRhi':[117,118,119,120],
    'Immune_ILC3_NCRlo':[106,107],
    'Immune_NK_CD16hi':[79,81,82,84],
    'Immune_uNK1':[49],
    'Immune_uNK2':[48,113],
    'Immune_uNK3':[50,51,53,55],
    'Immune_NK_CD56dim_CD16dim_SPTSSBhi':[99],
    'Immune_NK_Cyc':[39,40,42,44],
    
    'Immune_Mono/Mac/cDC2':[11,12,13,14,15,16,17,3,36,4,58,62,63,7,8,96,97,98],

        'doublet': [2,5,22,37],
        # 'soup': [],
        # 'lowQC': [],
        'donor_specific': [85],
        # 'unknown': [],
}


# Convert integers to strings
celltype_to_leiden = {k: [str(v) for v in vals] for k, vals in celltype_to_leiden.items()}

# ── Validate Leiden IDs ───────────────────────────────────────────────────────
_all_assigned = [lid for lids in celltype_to_leiden.values() for lid in lids]
_all_leiden   = sorted(adata.obs[LEIDEN_COL].unique().tolist())
_dups         = [x for x in _all_assigned if _all_assigned.count(x) > 1]
_unassigned   = [x for x in _all_leiden if x not in _all_assigned]

if _dups:
    print(f"WARNING — clusters assigned to multiple cell types: {sorted(set(_dups))}")
if _unassigned:
    print(f"INFO    — clusters not yet assigned              : {_unassigned}")
if not _dups and not _unassigned:
    print("All clusters assigned, no duplicates.")

# %%
# Invert: leiden_id → celltype
leiden_to_celltype = {
    lid: celltype
    for celltype, lids in celltype_to_leiden.items()
    for lid in lids
}

adata.obs["celltype"] = (
    adata.obs[LEIDEN_COL]
    .map(leiden_to_celltype)
    .astype("category")
)

print("Celltype distribution:")
print(adata.obs["celltype"].value_counts())

# %%
adata.obs.head(1)

# %%
# Add monocyte/macrophage annotations
adata.obs["celltype"] = adata.obs["celltype"].astype(str)

mask = adata.obs["celltype"] == "Immune_Mono/Mac/cDC2"

adata.obs.loc[mask, "celltype"] = (
    adata.obs.loc[mask, "acrosslifespan_noHormones_MonoMaccDC2_celltype"].astype(str)
)

adata.obs["celltype"] = adata.obs["celltype"].astype("category")

adata.obs["celltype"] = (
    adata.obs["celltype"]
    # .cat.add_categories(["NEED_ASSIGN"])
    .replace("nan", "doublet")
)

print("Celltype distribution:")
print(adata.obs["celltype"].value_counts())

# %%
# Order categories
celltype_order = [
    "Immune_HPC",
    "Immune_MEMP",
    "Immune_NMP_Promyelocytes",
    
    "Immune_BasoEosino",
    "Immune_Neutrophils",
    "Immune_Mast",
    
    "Immune_MegaPlat",
    "Immune_EarlyMidErythroid",
    "Immune_LateErythroid",
    
    "Immune_MO_Classical",
    "Immune_MO_NonClassical",
    # "Immune_MO_ISGs_nEMC",
    
    "Immune_Mac_LYVE1hi",
    "Immune_Mac_Transitional",
    "Immune_uftLAM",
    "Immune_oLAM",
    "Immune_uMac_Inf",
    # "Immune_Mac_SIGLEC15hi_nEMC",
    "Immune_Mac_Cyc",
    
    "Immune_cDC1",
    "Immune_cDC2",
    "Immune_cDC2_CD207hi",
    "Immune_pDC",
    "Immune_ASDC",
    "Immune_mregDC",
    "Immune_tolDC",
    
    "Immune_ProB",
    "Immune_LargePreB",
    "Immune_SmallPreB",
    "Immune_ImmatureB",
    "Immune_NaiveB",
    "Immune_MemoryB",
    "Immune_Plasma_κ",
    "Immune_Plasma_λ",
    
    "Immune_CD4_NaiveT",
    "Immune_CD4_T_Unpolarised",
    "Immune_CD4_Th17",
    "Immune_CD4_Th17_SCMlike",
    "Immune_CD4_Treg",
    "Immune_CD8_NaiveT",
    "Immune_CD8_T_RM",
    "Immune_CD8_T_RM_GZMKhi",
    "Immune_CD8_T_EM",
    "Immune_MAIT",
    "Immune_NKT_γδT_Vδ1",
    "Immune_γδT_Vγ9Vδ2",
    "Immune_T_Cyc",
    "Immune_CD4_Treg_Cyc",
    
    "Immune_ILC3_NCRhi",
    "Immune_ILC3_NCRlo",
    "Immune_NK_CD16hi",
    "Immune_uNK1",
    "Immune_uNK2",
    "Immune_uNK3",
    "Immune_NK_CD56dim_CD16dim_SPTSSBhi",
    "Immune_NK_Cyc",
    
    "doublet",  
    "lowQC",
    "donor_specific"
]

adata.obs["celltype"] = adata.obs["celltype"].cat.reorder_categories(
    celltype_order,
    ordered=True
)

print("Celltype distribution:")
print(adata.obs["celltype"].value_counts())

# %%
# celltype_leiden = "<celltype>_<leiden>"
adata.obs["celltype_leiden"] = (
    adata.obs["celltype"].astype(str)
    + "_"
    + adata.obs[LEIDEN_COL].astype(str)
).astype("category")

print("Celltype_leiden categories:", sorted(adata.obs["celltype_leiden"].cat.categories.tolist()))

# %% [markdown]
# ## Map cell ontology

# %% [markdown]
# Map HCA-approved cell ontology, containing levels (L) 1 through 4.

# %%
ontology_info = pd.read_csv(ONTOLOGY_CSV)
ontology_info.tail(5)

# %%
ONTOLOGY_COLS = [
    "celltype_HCA",
    "L1",
    "L2",
    "L3",
    "L4"
]

cell_ontology = ontology_info[ONTOLOGY_COLS]
cell_ontology.head(1)

# %%
adata.obs.head(1)

# %%
adata.obs.drop(columns=['celltype_HCA', 'L1', 'L2', 'L3', 'L4'], inplace=True)

# %%
new_obs = adata.obs.merge(
    cell_ontology, 
    how='left',
    left_on="celltype",
    right_on="celltype_HCA"
)

new_obs.index = adata.obs.index
new_obs.head(1)

# %%
adata.obs = new_obs
adata.obs.head(1)

# %%
adata.obs['L4'].isna().sum()

# %% [markdown]
# ## Validation UMAPs

# %%
adata.obs.head(1)

# %%
col = "L4"
adata.obs[col] = adata.obs[col].fillna(adata.obs["celltype"])

# %%
adata.obs[col].isna().sum()

# %%
adata.obs[col].value_counts()

# %%
adata.obs["celltype_HCA"].value_counts()

# %%
ANNOT_COL = "celltype_HCA"

sc.pl.umap(
    adata,
    color           = ANNOT_COL,
    # legend_loc      = "on data",
    legend_fontsize = 7,
    title           = ANNOT_COL,
    save            = f"_05_{ANNOT_COL}_acrosslifespan_noHormones_immune_legend.pdf",
)

# %% [markdown]
# # 8. Save

# %%
adata.obs.head(1)

# %%
adata.obs_names = adata.obs["Loupe_barcodes"]
adata.write_h5ad(FORANNOTION_H5AD)
print(f"Annotated object saved → {FORANNOTION_H5AD}")

# %%
# Remove unncessary/redundant columns for final annotated object
COLS = [
    'HECA_celltype',
    'ECTOPIC_cell_coarse',
    'ECTOPIC_cell_type',
    'ECTOPIC_cell_state',
    'ovaries2026_celltype_UPDATED',
    'postnatal_immune_celltype',
    'fetal_immune_celltype',
    'acrosslifespan_Hormones_immune_celltype',
    'acrosslifespan_noHormones_MonoMaccDC2_celltype',
    'Loupe_barcodes',
    # 'sample_id_barcode_copy',
    'leiden_R',
    'celltype',
    'celltype_leiden'
]

adata.obs.drop(columns=COLS, inplace=True)

# %%
adata.obs.head(1)

# %%
adata.obs_names = adata.obs["sample_id_barcode_copy"]
adata.obs.index.name = "barcode" 

adata.write_h5ad(ANNOTATED_H5AD)
print(f"Annotated object saved → {ANNOTATED_H5AD}")

# %%
print("Organ distribution across all cells:")
print(adata.obs["Organ"].value_counts())

# %% [markdown]
# ## Save obs for annotations

# %%
# ── Save annotations ────────────────────────────────—————————————
adata.obs.to_csv(
    f'{OUTPUT_DIR}20260514_acrosslifespan_noHormones_immune_annotations.csv',
    index=True,
    index_label='barcode'
)

# %% [markdown]
# # 9. Barplots

# %%
BARPLOT_COLS = [
    "Organ_part",
    # LEIDEN_COL
]

PROP_COL = "celltype"

_n_groups = adata.obs[PROP_COL].nunique()
_height   = max(0.25, _n_groups * 0.25)

for col in BARPLOT_COLS:
    if col not in adata.obs.columns:
        print(f"Skipping '{col}' — not found in obs.")
        continue
    Barplot(PROP_COL, adata, var=col, height=8)
    
    plt.savefig(f"{OUTPUT_DIR}figures/barplot_{col}_{PROP_COL}_acrosslifespan_noHormones_immune_monomacscDC2.png", dpi=300, bbox_inches="tight")
    plt.show()

# %%
BARPLOT_COLS = [
    "celltype_HCA",
    # LEIDEN_COL
]

PROP_COL = "Organ"

_n_groups = adata.obs[PROP_COL].nunique()
_height   = max(0.25, _n_groups * 0.25)

for col in BARPLOT_COLS:
    if col not in adata.obs.columns:
        print(f"Skipping '{col}' — not found in obs.")
        continue
    Barplot(PROP_COL, adata, var=col, height=18)
    
    plt.savefig(f"{OUTPUT_DIR}figures/barplot_{col}_{PROP_COL}_acrosslifespan_noHormones_immune_monomacscDC2.png", dpi=300, bbox_inches="tight")
    plt.show()

# %%
BARPLOT_COLS = [
    "celltype_HCA",
    # LEIDEN_COL
]

PROP_COL = "Organ_part"

_n_groups = adata.obs[PROP_COL].nunique()
_height   = max(0.25, _n_groups * 0.25)

for col in BARPLOT_COLS:
    if col not in adata.obs.columns:
        print(f"Skipping '{col}' — not found in obs.")
        continue
    Barplot(PROP_COL, adata, var=col, height=18)
    
    plt.savefig(f"{OUTPUT_DIR}figures/barplot_{col}_{PROP_COL}_acrosslifespan_noHormones_immune_monomacscDC2.png", dpi=300, bbox_inches="tight")
    plt.show()
