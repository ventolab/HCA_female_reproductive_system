# %% [markdown]
# # 02ai · Integration with scVI (**Cross-organ ILCs** analytical manifold, acrosslifespan/noEMC)
#
# This script generates the integrated .h5ad object necessary for the annotation and subsequent analysis of innate lymphoid cells (ILCs; NK cells and ILC3s) in the **Human Female Reproductive System Cell Atlas v1,** excluding cells from donors taking exogenous hormones (EMC), and healthy ILCs from following publically available datasets:
#
# * Colon: [Uzzan et al., 2022](https://www.nature.com/articles/s41591-022-01680-y)
# * Lung: [Habermann et al., 2020](https://www.science.org/doi/10.1126/sciadv.aba1972) and [Natri et al., 2024](https://www.nature.com/articles/s41588-024-01702-0)
# * Oral cavity: [Williams et al., 2021](https://www.sciencedirect.com/science/article/pii/S0092867421006309?via%3Dihub)
#
# **Pipeline:**
# 1. Extract target barcodes froxm annotation `.csv`
# 2. For each h5ad: load → subset to target barcodes → save to a dedicated temp folder
# 3. Concatenate subsetted files on-disk: `join='outer'` (union of genes) and `join='inner'` (shared genes)
# 4. Inner concat → HVGs (`seurat_v3`) → scVI (`Dataset` batch, `Donor_id` covariate)
# 5. Transfer `X_scVI` to outer concat → KNN → UMAP → Leiden
# 6. Save integrated object

# %% [markdown]
# ## Configuration

# %%
import os

# ── Paths ─────────────────────────────────────────────────────────────────────
OBJECT     = "crossdisease_ILC"
MAIN_DIR   = "/nfs/team292/projects/PanTissue/"
INPUT_DIR  = os.path.join(MAIN_DIR, "results/temp/anndata_copy_freeze/")
H5AD_PATHS_LOAD = {
    "IPF_NatGen2024_vl6": "/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/IPF_NatGen2024_ILC_vl6.h5ad",
    "IPF_SciAdv2020_vl6": "/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/IPF_SciAdv2020_ILC_vl6.h5ad",
    "Periodontitis_vl6": "/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/Periodontitis_ILC_vl6.h5ad",
    "UlcerativeColitis_vl6": "/nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/UlcerativeColitis_ILC_vl6.h5ad"
}

# Annotation CSV
ANNOTATION_CSV = os.path.join(MAIN_DIR, "results/temp/02_annotation/immune/acrosslifespan/noHormones/20260514_acrosslifespan_noHormones_immune_annotations.csv")
LINEAGE_COL    = "L3"
LINEAGE_TARGET = [
    "ILC",
    "NK cells"
]

# Temporary folder for per-dataset subsetted h5ads (created here, used for concat)
SUBSET_DIR = os.path.join(MAIN_DIR, f"results/temp/00_preprocessing_othertissue_ILC/")

# Integration outputs
OUTPUT_DIR        = os.path.join(MAIN_DIR, "results/temp/01_integration/")
CONCAT_H5AD_OUTER = os.path.join(OUTPUT_DIR, f"concat_{OBJECT}_outer.h5ad")
CONCAT_H5AD_INNER = os.path.join(OUTPUT_DIR, f"concat_{OBJECT}_inner.h5ad")
INTEGRATED_H5AD   = os.path.join(OUTPUT_DIR, f"integrated_scvi_{OBJECT}.h5ad")
SCVI_MODEL_DIR    = os.path.join(OUTPUT_DIR, f"scvi_model_{OBJECT}")

os.makedirs(SUBSET_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── HVG parameters ───────────────────────────────────────────────────────────
N_HVG      = 3000   # fewer cells → fewer HVGs to avoid over-fitting
HVG_FLAVOR = "seurat_v3"
HVGs_BATCH_COL   = None  # column used as batch key for HVGs calculation

# ── scVI batch Column names in obs ───────────────────────────────────────────────────────
DATASET_COL      = "Dataset"   # batch key for scVI
DONOR_COL        = "Donor_id"  # covariate key for scVI
CELL_CYCLE_PHASE = "phase"     # covariate key for scVI

# ── scVI parameters ───────────────────────────────────────────────────────────
N_LATENT        = 60
N_LAYERS        = 2
GENE_LIKELIHOOD = "nb"
MAX_EPOCHS      = 200
EARLY_STOPPING  = True
DISPERSION      = 'gene-batch' #gene-batch

# ── Neighbours / UMAP parameters ─────────────────────────────────────────────
N_NEIGHBORS       = 20
LEIDEN_RESOLUTION = 1

# ── Misc ─────────────────────────────────────────────────────────────────────
RANDOM_SEED = 42
N_CPUS      = 8

# %% [markdown]
# ## Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import gc
import glob as glob_mod

import numpy as np
import pandas as pd
import scipy.sparse as sp
import matplotlib.pyplot as plt
import anndata as ad
import scanpy as sc
import scvi
from anndata.experimental import concat_on_disk

sc.settings.verbosity = 3
sc.settings.n_jobs    = N_CPUS
sc.set_figure_params(dpi=100, frameon=False, figsize=(6, 5))
ad.settings.allow_write_nullable_strings = True

print(f"anndata  : {ad.__version__}")
print(f"scanpy   : {sc.__version__}")
print(f"scvi     : {scvi.__version__}")
# Out:
# anndata  : 0.12.6
# scanpy   : 1.12
# scvi     : 1.4.2

# %% [markdown]
# ## 1 · Load annotation and identify immune barcodes

# %%
if not os.path.exists(ANNOTATION_CSV):
    raise FileNotFoundError(
        f"Annotation CSV not found: {ANNOTATION_CSV}\n"
        "Run 03_annotation_postnatal.ipynb first."
    )

ann = pd.read_csv(ANNOTATION_CSV, index_col="barcode")
print(f"Annotation CSV loaded: {len(ann):,} cells total")
print(f"\nLineage distribution:")
print(ann[LINEAGE_COL].value_counts())
# Out:
# Annotation CSV loaded: 228,611 cells total
#
# Lineage distribution:
# L3
# T cells                            91851
# Macrophages                        47280
# NK cells                           35634
# Monocytes                          15881
# B cells                            11854
# Conventional DC                     6063
# doublet                             5789
# Granulocytes                        5534
# Non-conventional DC                 2896
# ILC                                 2838
# donor_specific                      1482
# Myeloid progenitors                  536
# lowQC                                473
# Haematopoietic progenitor cells      211
# Megakaryocytes/platelets             177
# Erythroid                            112
# Name: count, dtype: int64

# %%
selected_barcodes = set(ann.index[ann[LINEAGE_COL].isin(LINEAGE_TARGET)])
lineage_str = ", ".join(LINEAGE_TARGET)
print(f"{lineage_str} barcodes identified: {len(selected_barcodes):,}")
# Out:
# ILC, NK cells barcodes identified: 38,472

# %% [markdown]
# ## 2 · Subset individual h5ads
#
# Each postnatal dataset is loaded individually, subset to immune barcodes, and saved to `SUBSET_DIR`.
# This keeps peak memory proportional to a single dataset rather than the full atlas.

# %%
# ── Discover source h5ads ───────────────────────────────────────────────
all_paths = sorted(glob_mod.glob(os.path.join(INPUT_DIR, "*.h5ad")))
source_paths = all_paths

if len(source_paths) == 0:
    raise FileNotFoundError(
        f"No h5ad files found in {INPUT_DIR}\n"
        "Expected filenames containing '.h5ad'."
    )

print(f"Source datasets ({len(source_paths)}):")
for p in source_paths:
    print(f"  {os.path.basename(p)}")
# Out:
# Source datasets (27):
#   cervix_adult_Guo2023-denoised.h5ad
#   fallopiantube_adult_sanger-denoised.h5ad
#   fallopiantube_adult_urlich2022-denoised.h5ad
#   fallopiantube_adult_weigert2025-denoised.h5ad
#   gonad_fetal_lardenois2026-denoised.h5ad
#   gonad_fetal_taelman2024-denoised.h5ad
#   ovary_adult_gaylord2025-denoised.h5ad
#   ovary_adult_guahmich2023-denoised.h5ad
#   ovary_adult_jones2024-denoised.h5ad
#   ovary_adult_sanger-denoised.h5ad
#   ovary_adult_wagner2020-denoised.h5ad
#   ovary_fetal_garciaalonso2022-denoised.h5ad
#   ovary_fetal_wamaitah-denoised.h5ad
#   ovary_paediatric_sanger-denoised.h5ad
#   reptract_fetal_lorenzi2025-denoised.h5ad
#   uterus_adult_Huang2023-denoised.h5ad
#   uterus_adult_Liu2025-denoised.h5ad
#   uterus_adult_Wang2020-denoised.h5ad
#   uterus_adult_burns2026-denoised.h5ad
#   uterus_adult_garciaalonso2021-denoised.h5ad
#   uterus_adult_mareckova2024-denoised.h5ad
#   uterus_adult_menstrualfluid_sanger-denoised.h5ad
#   uterus_adult_sanger-denoised.h5ad
#   uterus_adult_tan2022-denoised.h5ad
#   uterus_adult_urlich2024-denoised.h5ad
#   uterus_menopause_sanger-denoised.h5ad
#   vagina_adult_li2021-denoised.h5ad

# %%
skipped = []

for src_path in source_paths:
    name     = os.path.splitext(os.path.basename(src_path))[0]
    out_path = os.path.join(SUBSET_DIR, f"{name}.h5ad")

    if os.path.exists(out_path):
        print(f"  {name}: subset already exists — skipping.")
        continue

    print(f"  {name}: loading …", end=" ", flush=True)
    adata = ad.read_h5ad(src_path)
    
    # 1. Select barcodes in selected_barcodes
    combined_mask = adata.obs_names.isin(selected_barcodes)
    
    # 2. Add Menstrual Stage filter ONLY if the list is not None
    # if selected_menstrual_stages is not None:
    #     adata.obs["Menstrual_stage_short"] = (
    #         adata.obs['Menstrual_stage'].astype(str).str.split(" ").str[0]
    #     )
    #     mask_stage = adata.obs.Menstrual_stage_short.isin(selected_menstrual_stages)
    #     combined_mask &= mask_stage  # Update mask with AND logic
    
    n_keep = int(combined_mask.sum())
    print(f"{adata.n_obs:,} cells → {n_keep:,} kept", end=" ", flush=True)

    if n_keep < 5:
        print(f"— < 5 cells after filtering, skipping.")
        skipped.append(name)
        del adata
        gc.collect()
        continue

    # Subset and save
    adata_subset = adata[combined_mask].copy()
    del adata
    gc.collect()

    adata_subset.write_h5ad(out_path)
    print(f"→ saved.")
    del adata_subset
    gc.collect()

print(f"\nDone. Skipped datasets: {skipped if skipped else 'none'}")
# Out:
#   cervix_adult_Guo2023-denoised: subset already exists — skipping.
#   fallopiantube_adult_sanger-denoised: subset already exists — skipping.
#   fallopiantube_adult_urlich2022-denoised: subset already exists — skipping.
#   fallopiantube_adult_weigert2025-denoised: subset already exists — skipping.
#   gonad_fetal_lardenois2026-denoised: subset already exists — skipping.
#   gonad_fetal_taelman2024-denoised: subset already exists — skipping.
#   ovary_adult_gaylord2025-denoised: subset already exists — skipping.
#   ovary_adult_guahmich2023-denoised: loading … 45,561 cells → 0 kept — < 5 cells after filtering, skipping.
#   ovary_adult_jones2024-denoised: subset already exists — skipping.
#   ovary_adult_sanger-denoised: subset already exists — skipping.
#   ovary_adult_wagner2020-denoised: subset already exists — skipping.
#   ovary_fetal_garciaalonso2022-denoised: subset already exists — skipping.
#   ovary_fetal_wamaitah-denoised: subset already exists — skipping.
#   ovary_paediatric_sanger-denoised: subset already exists — skipping.
#   reptract_fetal_lorenzi2025-denoised: subset already exists — skipping.
#   uterus_adult_Huang2023-denoised: subset already exists — skipping.
#   uterus_adult_Liu2025-denoised: subset already exists — skipping.
#   uterus_adult_Wang2020-denoised: subset already exists — skipping.
#   uterus_adult_burns2026-denoised: subset already exists — skipping.
#   uterus_adult_garciaalonso2021-denoised: subset already exists — skipping.
#   uterus_adult_mareckova2024-denoised: subset already exists — skipping.
#   uterus_adult_menstrualfluid_sanger-denoised: subset already exists — skipping.
#   uterus_adult_sanger-denoised: subset already exists — skipping.
#   uterus_adult_tan2022-denoised: subset already exists — skipping.
#   uterus_adult_urlich2024-denoised: subset already exists — skipping.
#   uterus_menopause_sanger-denoised: subset already exists — skipping.
#   vagina_adult_li2021-denoised: subset already exists — skipping.
#
# Done. Skipped datasets: ['ovary_adult_guahmich2023-denoised']

# %% [markdown]
# ## 3 · Concatenate subsetted files on disk

# %%
# ── Collect the subsetted h5ads ───────────────────────────────────────────────
subset_paths = sorted(glob_mod.glob(os.path.join(SUBSET_DIR, "*.h5ad")))

if len(subset_paths) == 0:
    raise FileNotFoundError(f"No subsetted h5ad files found in {SUBSET_DIR}")

in_files = {
    os.path.splitext(os.path.basename(p))[0]: p
    for p in subset_paths
}

# —— Add adata_ilc to concat dict —————————————————————————————————————————————
for k,v in H5AD_PATHS_LOAD.items():
    in_files[k] = v

print(f"Datasets to concatenate ({len(in_files)}):")
for k, v in in_files.items():
    print(f"  {k:50s}  {v}")
# Out:
# Datasets to concatenate (30):
#   cervix_adult_Guo2023-denoised                       /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/cervix_adult_Guo2023-denoised.h5ad
#   fallopiantube_adult_sanger-denoised                 /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/fallopiantube_adult_sanger-denoised.h5ad
#   fallopiantube_adult_urlich2022-denoised             /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/fallopiantube_adult_urlich2022-denoised.h5ad
#   fallopiantube_adult_weigert2025-denoised            /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/fallopiantube_adult_weigert2025-denoised.h5ad
#   gonad_fetal_lardenois2026-denoised                  /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/gonad_fetal_lardenois2026-denoised.h5ad
#   gonad_fetal_taelman2024-denoised                    /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/gonad_fetal_taelman2024-denoised.h5ad
#   ovary_adult_gaylord2025-denoised                    /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_adult_gaylord2025-denoised.h5ad
#   ovary_adult_jones2024-denoised                      /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_adult_jones2024-denoised.h5ad
#   ovary_adult_sanger-denoised                         /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_adult_sanger-denoised.h5ad
#   ovary_adult_wagner2020-denoised                     /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_adult_wagner2020-denoised.h5ad
#   ovary_fetal_garciaalonso2022-denoised               /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_fetal_garciaalonso2022-denoised.h5ad
#   ovary_fetal_wamaitah-denoised                       /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_fetal_wamaitah-denoised.h5ad
#   ovary_paediatric_sanger-denoised                    /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/ovary_paediatric_sanger-denoised.h5ad
#   reptract_fetal_lorenzi2025-denoised                 /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/reptract_fetal_lorenzi2025-denoised.h5ad
#   uterus_adult_Huang2023-denoised                     /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_Huang2023-denoised.h5ad
#   uterus_adult_Liu2025-denoised                       /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_Liu2025-denoised.h5ad
#   uterus_adult_Wang2020-denoised                      /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_Wang2020-denoised.h5ad
#   uterus_adult_burns2026-denoised                     /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_burns2026-denoised.h5ad
#   uterus_adult_garciaalonso2021-denoised              /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_garciaalonso2021-denoised.h5ad
#   uterus_adult_mareckova2024-denoised                 /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_mareckova2024-denoised.h5ad
#   uterus_adult_menstrualfluid_sanger-denoised         /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_menstrualfluid_sanger-denoised.h5ad
#   uterus_adult_sanger-denoised                        /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_sanger-denoised.h5ad
#   uterus_adult_tan2022-denoised                       /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_tan2022-denoised.h5ad
#   uterus_adult_urlich2024-denoised                    /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_adult_urlich2024-denoised.h5ad
#   uterus_menopause_sanger-denoised                    /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/uterus_menopause_sanger-denoised.h5ad
#   vagina_adult_li2021-denoised                        /nfs/team292/projects/PanTissue/results/temp/00_preprocessing_othertissue_ILC/vagina_adult_li2021-denoised.h5ad
#   IPF_NatGen2024_vl6                                  /nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/IPF_NatGen2024_ILC_vl6.h5ad
#   IPF_SciAdv2020_vl6                                  /nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/IPF_SciAdv2020_ILC_vl6.h5ad
#   Periodontitis_vl6                                   /nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/Periodontitis_ILC_vl6.h5ad
#   UlcerativeColitis_vl6                               /nfs/team292/projects/PanTissue/results/temp/02_annotation/immune/acrosslifespan/noHormones/04_crossdisease_ILC/UlcerativeColitis_ILC_vl6.h5ad

# %%
# ── Outer concat (union of genes) ────────────────────────────────────────────
if os.path.exists(CONCAT_H5AD_OUTER):
    print(f"Outer concat already exists: {CONCAT_H5AD_OUTER}\nSkipping.")
else:
    print("Concatenating (outer — union of genes) …")
    concat_on_disk(
        in_files = in_files,
        out_file = CONCAT_H5AD_OUTER,
        join     = "outer",
        label    = DATASET_COL,
    )
    print(f"Saved → {CONCAT_H5AD_OUTER}")

# ── Inner concat (intersection of genes) ─────────────────────────────────────
if os.path.exists(CONCAT_H5AD_INNER):
    print(f"Inner concat already exists: {CONCAT_H5AD_INNER}\nSkipping.")
else:
    print("Concatenating (inner — intersection of genes) …")
    concat_on_disk(
        in_files = in_files,
        out_file = CONCAT_H5AD_INNER,
        join     = "inner",
        label    = DATASET_COL,
    )
    print(f"Saved → {CONCAT_H5AD_INNER}")
# Out:
# Concatenating (outer — union of genes) …
# Saved → /nfs/team292/projects/PanTissue/results/temp/01_integration/concat_crossdisease_ILC_outer.h5ad
# Concatenating (inner — intersection of genes) …
# Saved → /nfs/team292/projects/PanTissue/results/temp/01_integration/concat_crossdisease_ILC_inner.h5ad

# %%
print("Loading inner concat (intersection of genes) …")
adata_inner = ad.read_h5ad(CONCAT_H5AD_INNER)

# ── Guard against duplicate barcodes ─────────────────────────────────────────
dup_mask = adata_inner.obs_names.duplicated()
if dup_mask.any():
    n_dup = int(dup_mask.sum())
    print(f"WARNING: {n_dup} duplicate barcodes — deduplicating (keeping first).")
    adata_inner = adata_inner[~dup_mask].copy()

# ── Fix sparse matrix dtype mismatch (concat_on_disk can mix int32/int64) ────
if sp.issparse(adata_inner.X) and adata_inner.X.indptr.dtype != adata_inner.X.indices.dtype:
    target_dtype = np.result_type(adata_inner.X.indptr.dtype, adata_inner.X.indices.dtype)
    print(f"Fixing sparse dtype mismatch: indptr={adata_inner.X.indptr.dtype}, "
          f"indices={adata_inner.X.indices.dtype} → {target_dtype}")
    adata_inner.X.indptr  = adata_inner.X.indptr.astype(target_dtype)
    adata_inner.X.indices = adata_inner.X.indices.astype(target_dtype)

print(f"inner : {adata_inner.n_obs:,} cells × {adata_inner.n_vars:,} genes")
print("\nobs columns:", adata_inner.obs.columns.tolist())
# Out:
# Loading inner concat (intersection of genes) …
# inner : 59,967 cells × 14,509 genes
#
# obs columns: ['n_genes', 'percent_mito', 'doublet_scores', 'S_score', 'G2M_score', 'phase', 'Dataset', 'Donor_id']

# %%
adata_inner.obs[DATASET_COL].value_counts()
# Out:
# Dataset
# IPF_NatGen2024_vl6                             11126
# uterus_adult_Huang2023-denoised                 7979
# IPF_SciAdv2020_vl6                              7456
# uterus_adult_urlich2024-denoised                4399
# uterus_adult_Liu2025-denoised                   3750
# uterus_adult_sanger-denoised                    3530
# uterus_adult_burns2026-denoised                 3468
# uterus_adult_menstrualfluid_sanger-denoised     2881
# uterus_adult_garciaalonso2021-denoised          2665
# Periodontitis_vl6                               2303
# uterus_adult_Wang2020-denoised                  1453
# fallopiantube_adult_weigert2025-denoised        1418
# fallopiantube_adult_sanger-denoised             1346
# uterus_adult_tan2022-denoised                   1219
# fallopiantube_adult_urlich2022-denoised          785
# uterus_menopause_sanger-denoised                 735
# cervix_adult_Guo2023-denoised                    682
# UlcerativeColitis_vl6                            610
# ovary_fetal_garciaalonso2022-denoised            602
# uterus_adult_mareckova2024-denoised              586
# vagina_adult_li2021-denoised                     294
# reptract_fetal_lorenzi2025-denoised              201
# ovary_paediatric_sanger-denoised                 140
# ovary_adult_jones2024-denoised                   115
# ovary_adult_sanger-denoised                      107
# gonad_fetal_lardenois2026-denoised                46
# ovary_fetal_wamaitah-denoised                     46
# gonad_fetal_taelman2024-denoised                  13
# ovary_adult_gaylord2025-denoised                   6
# ovary_adult_wagner2020-denoised                    6
# Name: count, dtype: int64

# %%
donors = adata_inner.obs[DONOR_COL].unique()
print(', '.join(donors))
# Out:
# N1_NO_HPV, N2_NO_HPV, CW6, CW21, A22, FT2, FT3, FT4, D2_3508 (D10), D5_3619 (D13), D6_3636 (D14), D7_3643 (D15), D9_3669 (D17), D10_3679 (D18), D3_3203 (D3), D4_3295 (D4), D5_3296 (D5), D6_3369 (D6), D7_3391 (D7), D1_2509 (D9), f2, f3, f15, f4, f5, f6, f8, f11, f14, f16, f1, G2_2nd_trimester, TSP27, TSP30, Donor 3, Donor 4, Donor 5, A30, M17, M20, M21, M22, M23, M6, M7, M10, pool of donors, GRD1, Hrv86, F89, Hrv11, Hrv30, Hrv34, F123, Hrv92, Hrv93, Hrv99, Hrv37, F126, Hrv39, Hrv49, Hrv85, Hrv58, Hrv59, Hrv57, F133, F86, F99, F87, F91, F96, F83, W7, W9, W10, W13, W16, AUrv5, AUrv6, AUrv10, AUrv11, AUrv13, AUrv14, AUrv15, AUrv16, AUrv17, AUrv18, AUrv19, AUrv21, AUrv24, AUrv25, AUrv26, AUrv28, AUrv29, AUrv35, AUrv36, AUrv37, AUrv38, AUrv39, AUrv40, Hrv174, Hrv139, Hrv220, Hrv261, C112, C167, Hrv243, C140, C139, Hrv152, Hrv118, Hrv245, Hrv187, Hrv201, Hrv69, Hrv91, C142, C150, Hrv179, Hrv125, Hrv126, Hrv166, Hrv275, C152, GSM6605439, GSM6605440, GSM6605432, GSM6605433, GSM6605434, GSM6605437, GSM6605438, GSM6605431, GSM6605436, GSM7277296, GSM7277297, GSM7277298, p1, p2, p4, p5, p6, p7, p8, p9, p10, p11, p12, SAMN15049051, SAMN15049050, SAMN15049049, SAMN15049048, SAMN15049047, SAMN15049046, SAMN15049045, SAMN15049044, SAMN15049043, SAMN15049042, EMB44, EMB50, EMB51, EMB53, EMB52, EMB55, EMB57, EMB87, EMB66, EMB75, EMB88, A13, E1, E2, E3, A16, FX1125, FX1176, SE03, FX1259, FX1119, FX1146, FX9006, FX1156, SE02, FX1285, DM84, DM85, DM88, DM89, DM90, DM91, DM92, DM81, FX1341, FX1343, BZ15-END-0-FTM-1 (Control10), BZ14-END-0-FTM-1 (Control9), BZ17-END-0-FTM-1 (Control11), BZ19_END_0_FTM_1 (Control13), BZ20_END_0_FTM_1 (Control14), BZ21-END-0-FTM-4 (Patient7), BZ22_END_0_FTM_2 (Patient8), BZ27_END_0_FTM_1 (Patient13), BZ29_END_0_FTM_1 (Patient15), BZ32_END_0_FTM_1 (Patient18), BZ36_END_0_FTM_1 (Control15), BZ34_END_0_FTM_1 (Control17), BZ33_END_0_FTM_1 (Control16), BZ35_END_0_FTM_2 (Control18), DA8-END-0-FT-24  (Brno patient 8), BZ52_END_0_FTM_1 (Patient26), BZ59_END_0_FTM_1 (Control32), BZ61_END_0_FTM_1 (Control34), BZ62_END_0_FTM_1 (Control35), BZ66_END_0_FTM_1 (Control39), C03, E01, D1, D2, D3, D4, D5, D7, A14, A17, N2, N3, N4, N5, VUILD93, VUILD95, VUILD96, VUILD97, TILD084, THD0015, VUHD103, VUHD104, VUHD106, VUHD107, VUILD82, VUILD83, VUILD84, VUILD88, VUILD90, VUILD91, THD0019, TILD103, TILD116, VUILD100, THD0021, THD0022, THD0023, TILD123, TILD136, VUHD108, VUHD109, VUHD111, VUHD112, VUHD113, VUHD114, VUHD115, VUHD117, VUILD102, VUILD104, VUILD108, TILD109, TILD113, VUILD89, VUILD85, VUILD86, VUILD87, VUILD98, VUILD99, THD0007, THD0008, TILD049, TILD051, TILD055, TILD062, VUHD84, VUHD85, VUILD79, VUILD73, VUILD77, TILD039, TILD041, VUILD67, VUILD68, VUILD48, VUILD54, VUILD53, VUILD55, VUHD65, VUHD66, VUILD57, VUILD58, VUHD67, VUHD68, VUILD59-2, VUILD59-1, VUHD69, VUILD60-2, VUILD60-1, THD0001, VUILD61-2, VUILD61-1, VUHD70, VUILD62-1, VUILD62-2, TILD015, VUILD63, VUILD64, VUILD65, VUHD71, THD0002, THD0005, TILD006, TILD010, TILD028, TILD019, BM150, BM156, BM157, BM158, GM136, GM143, GM144, GM147, GM148, GM183, GM184a, GM238, GM241, GM242, PD134, PD153, PD161b, PD164, BM165, BM168, BM169, GM169, GM283, GM289, PD164b, PD164c, PD170, 198, 200, 202, 204, 206, 219, 221, 237, 238

# %% [markdown]
# ## 4 · Highly variable genes stratified by menstrual stage

# %%
sc.pp.filter_genes(adata_inner, min_cells=5)
# Out:
# filtered out 15 genes that are detected in less than 5 cells

# %%
print(f"Identifying {N_HVG} HVGs on inner concat "
      f"({adata_inner.n_vars:,} shared genes) …")

# Check if a batch column is provided and exists in obs
use_batch = (HVGs_BATCH_COL is not None) and (HVGs_BATCH_COL in adata_inner.obs)

if use_batch and adata_inner.obs[HVGs_BATCH_COL].nunique() > 1:
    print(f"Running HVG with batch key: {HVGs_BATCH_COL}")
    sc.pp.highly_variable_genes(
        adata_inner,
        n_top_genes = N_HVG,
        flavor      = HVG_FLAVOR,
        batch_key   = HVGs_BATCH_COL,
        subset      = False,
    )
else:
    # Logic for when HVGs_BATCH_COL is None OR there is only 1 unique batch
    reason = "no batch column provided" if not use_batch else "only one unique batch found"
    print(f"WARNING: Running HVG without stratification ({reason}).")
    
    sc.pp.highly_variable_genes(
        adata_inner,
        n_top_genes = N_HVG,
        flavor      = HVG_FLAVOR,
        subset      = False,
    )

inner_genes_set = set(adata_inner.var_names)
hvg_set         = set(adata_inner.var_names[adata_inner.var.highly_variable])
print(f"HVGs selected: {len(hvg_set)}")
sc.pl.highly_variable_genes(adata_inner)
# Out:
# Identifying 3000 HVGs on inner concat (14,494 shared genes) …
# WARNING: Running HVG without stratification (no batch column provided).
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# HVGs selected: 3000

# %%
adata_hvg = adata_inner[:, adata_inner.var.highly_variable].copy()
del adata_inner
gc.collect()
print(f"adata_hvg (HVGs only): {adata_hvg}")
# Out:
# adata_hvg (HVGs only): AnnData object with n_obs × n_vars = 59967 × 3000
#     obs: 'n_genes', 'percent_mito', 'doublet_scores', 'S_score', 'G2M_score', 'phase', 'Dataset', 'Donor_id'
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg'

# %% [markdown]
# ## 5 · Batch correction with scVI

# %%
adata_hvg.obs[DONOR_COL] = adata_hvg.obs[DONOR_COL].astype(str)

# %%
scvi.settings.seed = RANDOM_SEED

if DONOR_COL not in adata_hvg.obs.columns:
    raise ValueError(f"Column '{DONOR_COL}' not found. Available: {adata_hvg.obs.columns.tolist()}")

print(f"Number of donors: {adata_hvg.obs[DONOR_COL].nunique()}")
print(f"Number of datasets: {adata_hvg.obs[DATASET_COL].nunique()}")

scvi.model.SCVI.setup_anndata(
    adata_hvg,
    batch_key                  = DATASET_COL,
    categorical_covariate_keys = [DONOR_COL, CELL_CYCLE_PHASE],
)

model = scvi.model.SCVI(
    adata_hvg,
    n_latent        = N_LATENT,
    n_layers        = N_LAYERS,
    gene_likelihood = GENE_LIKELIHOOD,
    dispersion      = DISPERSION
)
model
# Out:
# Seed set to 42
# Number of donors: 354
# Number of datasets: 30
# SCVI model with the following parameters:
# n_hidden: 128, n_latent: 60, n_layers: 2, dropout_rate: 0.1, dispersion: gene-batch, gene_likelihood: nb,
# latent_distribution: normal.
# Training status: Not Trained
# Model's adata is minified?: False

# %%
model.train(
    max_epochs     = MAX_EPOCHS,
    early_stopping = EARLY_STOPPING,
)
model.save(SCVI_MODEL_DIR, overwrite=True)
print(f"Model saved → {SCVI_MODEL_DIR}")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB MIG 1g.10gb') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [MIG-GPU-cabed480-71db-8ae2-d02c-e01d42a2060d/13/0]
# Epoch 200/200: 100%|██████████| 200/200 [11:47<00:00,  3.51s/it, v_num=1, train_loss=987]
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 200/200: 100%|██████████| 200/200 [11:47<00:00,  3.54s/it, v_num=1, train_loss=987]
# Model saved → /nfs/team292/projects/PanTissue/results/temp/01_integration/scvi_model_crossdisease_ILC

# %%
X_scVI = model.get_latent_representation()

del adata_hvg
gc.collect()

print("Loading outer concat (union of genes) …")
adata = ad.read_h5ad(CONCAT_H5AD_OUTER)

# ── Guard against duplicate barcodes ─────────────────────────────────────────
dup_mask = adata.obs_names.duplicated()
if dup_mask.any():
    n_dup = int(dup_mask.sum())
    print(f"WARNING: {n_dup} duplicate barcodes — deduplicating (keeping first).")
    adata = adata[~dup_mask].copy()

# ── Fix sparse matrix dtype mismatch ─────────────────────────────────────────
if sp.issparse(adata.X) and adata.X.indptr.dtype != adata.X.indices.dtype:
    target_dtype = np.result_type(adata.X.indptr.dtype, adata.X.indices.dtype)
    print(f"Fixing sparse dtype mismatch: indptr={adata.X.indptr.dtype}, "
          f"indices={adata.X.indices.dtype} → {target_dtype}")
    adata.X.indptr  = adata.X.indptr.astype(target_dtype)
    adata.X.indices = adata.X.indices.astype(target_dtype)

print(f"outer : {adata.n_obs:,} cells × {adata.n_vars:,} genes")

adata.obsm["X_scVI"]         = X_scVI
adata.var["in_inner"]        = adata.var_names.isin(inner_genes_set)
adata.var["in_hvg"]          = adata.var_names.isin(hvg_set)
adata.var["highly_variable"] = adata.var["in_hvg"]

del X_scVI
print(f"X_scVI transferred: shape {adata.obsm['X_scVI'].shape}")
print(f"in_inner: {adata.var['in_inner'].sum():,} genes  |  in_hvg: {adata.var['in_hvg'].sum():,} genes")

model.history["elbo_train"].plot()
plt.title("ELBO – training")
plt.ylabel("ELBO")
plt.xlabel("Epoch")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f"scvi_{OBJECT}.png"), dpi=150)
plt.show()
# Out:
# Loading outer concat (union of genes) …
# outer : 59,967 cells × 36,009 genes
# X_scVI transferred: shape (59967, 60)
# in_inner: 14,494 genes  |  in_hvg: 3,000 genes

# %% [markdown]
# ## 6 · KNN graph, UMAP and Leiden clustering

# %%
import numba

print("Numba threads available:", numba.get_num_threads())
print("Numba config NUM_THREADS:", numba.config.NUMBA_NUM_THREADS)
print("CPUs visible to OS:", os.cpu_count())
print("CPUs in affinity mask:", len(os.sched_getaffinity(0)))
os.sched_setaffinity(0, range(64))
print("CPUs in affinity mask:", len(os.sched_getaffinity(0)))

from pynndescent import PyNNDescentTransformer

transformer = PyNNDescentTransformer(
    n_neighbors=N_NEIGHBORS,
    metric="euclidean",
    n_jobs=None,   # explicitly limit to 1
    random_state=RANDOM_SEED,
)
# Out:
# Numba threads available: 1
# Numba config NUM_THREADS: 1
# CPUs visible to OS: 64
# CPUs in affinity mask: 1
# CPUs in affinity mask: 1

# %%
_use_rapids = False
try:
    import rapids_singlecell as rsc
    import cupy as cp
    rsc.get.anndata_to_GPU(adata)
    rsc.pp.neighbors(
        adata,
        n_neighbors = N_NEIGHBORS+1,
        use_rep     = "X_scVI",
        algorithm   = "cagra",
        metric      = "euclidean",
    )
    rsc.get.anndata_to_CPU(adata)
    _use_rapids = True
    print("KNN computed with CAGRA (rapids_singlecell, GPU).")
except ImportError:
    print("rapids_singlecell not available — falling back to scanpy (pynndescent).")

if not _use_rapids:
    sc.pp.neighbors(
        adata,
        n_neighbors  = N_NEIGHBORS,
        use_rep      = "X_scVI",
        method       = "umap",
        # metric       = "euclidean",
        # random_state = RANDOM_SEED,
        transformer= transformer, # New, test with more cores to initialize jupyterlab
    )
    print("KNN computed with pynndescent (scanpy, CPU).")
# Out:
# rapids_singlecell not available — falling back to scanpy (pynndescent).
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:23)
# KNN computed with pynndescent (scanpy, CPU).

# %%
sc.tl.umap(adata, random_state=RANDOM_SEED)
print("UMAP coordinates stored in adata.obsm['X_umap'].")
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:28)
# UMAP coordinates stored in adata.obsm['X_umap'].

# %%
if _use_rapids:
    rsc.tl.leiden(
        adata,
        resolution   = LEIDEN_RESOLUTION,
        random_state = RANDOM_SEED,
        key_added    = "leiden",
    )
else:
    sc.tl.leiden(
        adata,
        resolution   = LEIDEN_RESOLUTION,
        random_state = RANDOM_SEED,
        key_added    = "leiden",
        flavor       = "igraph",
        n_iterations = 2,
        directed     = False,
    )
print(f"Leiden clusters (res={LEIDEN_RESOLUTION}): {adata.obs['leiden'].nunique()} clusters")
print(adata.obs["leiden"].value_counts().sort_index())
# Out:
# running Leiden clustering
#     finished: found 14 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)
# Leiden clusters (res=1): 14 clusters
# leiden
# 0     2785
# 1     5249
# 2     3076
# 3     9117
# 4     4079
# 5     5629
# 6     7663
# 7     1573
# 8     6631
# 9     8923
# 10     491
# 11    3780
# 12     667
# 13     304
# Name: count, dtype: int64

# %% [markdown]
# ## 7 · Save integrated object

# %%
sc.pl.umap(adata, color = DATASET_COL)

# %%
sc.pl.umap(adata, color = DONOR_COL)
# Out:
# the obs value 'Donor_id' has more than 103 categories. Uniform 'grey' color will be used for all categories.

# %%
adata.write_h5ad(INTEGRATED_H5AD)
print(f"Integrated object saved → {INTEGRATED_H5AD}")
print(adata)
# Out:
# Integrated object saved → /nfs/team292/projects/PanTissue/results/temp/01_integration/integrated_scvi_crossdisease_ILC.h5ad
# AnnData object with n_obs × n_vars = 59967 × 36009
#     obs: 'n_genes', 'percent_mito', 'doublet_scores', 'senescence_score', 'stress_score_vandenBrink', 'health_score', 'metabolic_activity', 'S_score', 'G2M_score', 'phase', 'sample', 'dataset', 'in_HCAv1', 'exclusion-inclusion_criteria', 'Organ', 'Dataset', 'Sample_id', 'Library_id', 'Donor_id', 'Sex', 'Postnatal_age_years', 'Gestational_age_pcw', 'Developmental_stage', 'Tanner Stage', 'Menstrual_stage', 'Disease', 'Clinical_diagnosis', 'Organ_part', 'Tissue_ROI', 'Specimen_type', 'Sampled_site_condition', 'Observed_pathology', 'Tissue_status', 'Dissociation_method', 'Cell_enrichment', 'Preservation_method', 'Target_cell_population', 'Sorting_method', 'Assay_type', 'Library_chemistry', 'Sequencing_platform', 'Multiplexed', 'Dataset_id', 'Batch', 'Collection_site', 'Sample_id_other', 'Menstrual_stage_OriginalAuthors', 'predicted_doublet', 'n_counts', 'sample_id', 'percent_ribo', 'project', 'Tissue', 'age', 'gender', 'Patient_status', 'batch', 'info', 'Diagnosis', 'smoking_status', 'leiden', 'leiden_R', 'leiden_2', 'immune_annotations', 'orig_barcode', 'Organism', 'Source_Name', 'Status'
#     var: 'in_inner', 'in_hvg', 'highly_variable'
#     uns: 'neighbors', 'umap', 'leiden', 'Dataset_colors', 'Donor_id_colors'
#     obsm: 'X_scVI', 'X_umap'
#     obsp: 'distances', 'connectivities'
