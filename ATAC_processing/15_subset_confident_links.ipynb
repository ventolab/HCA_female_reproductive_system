# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
links=read.csv("/nfs/team292/projects/PanTissue/results/freeze/ATAC/nonfetal_all/ArchRproj_subset/genefiles/peak2gene_links.csv")

# %%
head(links)
# Out:
#   idxATAC idxRNA Correlation FDR          VarQATAC  VarQRNA   geneName
# 1  33     11     0.6005109   2.656229e-08 0.9668777 0.2652881 FAM87B
# 2 116     11     0.5930539   4.643301e-08 0.9276664 0.2652881 FAM87B
# 3 154     11     0.5273422   3.493845e-06 0.6809746 0.2652881 FAM87B
# 4 243     11     0.4967756   1.899876e-05 0.7154563 0.2652881 FAM87B
# 5   3     12     0.4703327   7.148032e-05 0.5324975 0.7211730 LINC01128
# 6  12     12     0.4858853   3.327975e-05 0.5551324 0.7211730 LINC01128
#   peakName
# 1 chr1:905195-905695
# 2 chr1:980609-981109
# 3 chr1:1014969-1015469
# 4 chr1:1124095-1124595
# 5 chr1:807763-808263
# 6 chr1:830678-831178

# %%
final=links %>% filter(FDR<1e-5) %>% select(geneName,peakName,Correlation,FDR)

# %%
write.csv(final,"/nfs/team292/projects/PanTissue/results/freeze/ATAC/peak2gene/finalres/peak2gene_links_FDR1e-5.csv",quote=F, row.names=F)
